# %% [markdown]
# # Atividade Aula 3 - Feature 4

# %% [markdown]
# ### **Proposta:** Descobrir o vôo mais longo.

# %%
# !pip install pandas

import pandas as pd

df = pd.read_csv('C:\\Users\\guino\\OneDrive\\Documents\\Unesp\\6th Semestre\\DS\\datasets\\2006-sample.csv')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2006      4          10          1   1405.0        1410   1456.0
# 1  2006      1           3          2   1344.0        1321   2116.0
# 2  2006     11          26          7   1810.0        1725   2107.0
# 3  2006      1          25          3   2326.0        2323    737.0
# 4  2006      8          11          5   1409.0        1410   1628.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1505            MQ       3503  ...      2        8          0
# 1        2100            DL        461  ...      4       14          0
# 2        2025            WN       2308  ...      4       32          0
# 3         731            AS         10  ...      6        9          0
# 4        1632            US       1038  ...      3       10          0
#
# ...

# %%
df2 = df[df['Distance'] == df['Distance'].max()]

df2[['FlightNum', 'Distance']]
# Out:
#        FlightNum  DepDelay  Distance
# 7129         317      37.0      4502
# 8717        1282      -1.0      4502
# 17235       1282      -3.0      4502
# 51741        855      -1.0      4502
